# %%
import sklearn

# Pour pouvoir afficher des graphiques:
import matplotlib.pyplot as plt

# numpy
import numpy as np

import pandas as pd

# Pour afficher les graphiques dans la continuité du code, 
# et non pas dans une fenêtre à part:
# %matplotlib inline

import seaborn as sns

# %%
# Visualisation d’un nuage de points et exploration des variables 
# 1
house_data = pd.read_csv("D://Etudes/HiTeMa M2/BigData/data/house_pricing.csv")

# %%
# 2
house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
# 3
plt.scatter(house_data.LotArea,house_data.SalePrice)

# %%
# 4
house_data_affined = house_data[(house_data.LotArea < 20000) & (house_data.SalePrice < 500000)]
# house_data_affined = house_data_affined[house_data.SalePrice < 500000]

plt.scatter(house_data_affined.LotArea,house_data_affined.SalePrice)

# %%
# 5
plt.scatter(house_data.LotFrontage,house_data.LotArea)

# %%
# 6
house_data_affined = house_data[(house_data.LotFrontage < 200) & (house_data.LotArea < 100000)]

plt.scatter(house_data_affined.LotFrontage,house_data_affined.LotArea)

# %%
# Visualisation de relations continues 
# 1
sales_data = pd.read_csv("D://Etudes/HiTeMa M2/BigData/data/sales_predictions.csv")

# %%
sales_data
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %%
# 2
sns.relplot(x='date',y='item_id',data=sales_data)

# %%
# 3
sales_data_sample = sales_data.sample(50)

# %%
sales_data_sample
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 414983   12.04.2013               3       31     9842      149.00
# 546785   09.06.2013               5       41     1905      249.00
# 1685498  29.05.2014              16       56     7856      799.00
# 2032438  10.10.2014              21       30    14664      349.00
# 2233011  14.12.2014              23       35     9355      349.00
# 1081512  20.11.2013              10       17    15343      149.00
# 1767636  14.06.2014              17       56    15802      199.00
# 485670   14.05.2013               4       54     4161      849.00
# 2538187  13.03.2015              26       28    18434      149.00
# 978901   05.10.2013               9       51    12938      250.00
# 2247861  21.12.2014              23       40     9206     1799.00
# 2215937  06.12.2014              23       57    17104      399.00
# 2826844  28.08.2015              31       21     8607      449.00
# 2895532  12.10.2015              33       56    17717     1166.00
# 1694200  07.05.2014              16       35     4395     2999.00
# 2614032  05.05.2015              28       18    11776       99.00
# 552011   13.06.2013               5       45    11863        0.10
# 2486193  13.03.2015              26       44    16061     1999.00
# 75307    31.01.2013               0       56     8425      749.00
# 2064629  05.10.2014              21       18    14128      664.00
# 1367747  02.02.2014              13       28     1439     1000.00
# 1476765  02.03.2014              14       59     2766      384.00
# 1708586  22.06.2014              17       27     8415      349.00
# 2508267  22.03.2015              26       57    18822       49.00
# 2274757  20.12.2014              23       54     8469      349.00
# 1408593  09.02.2014              13       19    11903      349.00
# 1800042  07.07.2014              18       31     6457      699.00
# 232880   30.03.2013               2       42     4307     1349.00
# 2463691  10.02.2015              25        7     2882      999.00
# 2868461  22.09.2015              32       31     5821     1099.00
# 37703    03.01.2013               0        0     8070      137.00
# 1804353  11.07.2014              18       35    16205      319.00
# 2815046  12.08.2015              31       12     6092     1199.00
# 844011   15.09.2013               8       51    20237      200.00
# 1963158  04.09.2014              20       35     4382      149.00
# 2146846  28.11.2014              22       18     8687      199.00
# 1606497  05.04.2014              15       52    13027      199.00
# 676666   16.07.2013               6       21     5022      299.00
# 141277   02.02.2013               1       54     2920      598.75
# 147033   16.02.2013               1       18     7536      299.00
# 953368   18.10.2013               9       35     6883      299.00
# 1424681  26.02.2014              13       54    11306      399.00
# 2294588  13.12.2014              23       27    14143      699.00
# 2339517  02.01.2015              24        7     4178     1590.00
# 985880   31.10.2013               9       22     4308     2599.00
# 1056375  07.11.2013              10       31     9538       58.00
# 1549173  16.03.2014              14        7     7018     1199.00
# 952346   05.10.2013               9       31    19956      498.00
# 2805987  07.08.2015              31       14    16639      299.00
# 1993738  29.09.2014              20       31     1855      799.00
#
#          item_cnt_day
# 414983            1.0
# 546785            1.0
# 1685498           2.0
# 2032438           1.0
# 2233011          12.0
# 1081512           1.0
# 1767636           1.0
# 485670            2.0
# 2538187           1.0
# 978901            1.0
# 2247861           1.0
# 2215937           2.0
# 2826844           1.0
# 2895532           3.0
# 1694200           1.0
# 2614032           1.0
# 552011            1.0
# 2486193           1.0
# 75307             1.0
# 2064629           2.0
# 1367747           2.0
# 1476765           1.0
# 1708586           1.0
# 2508267           1.0
# 2274757           1.0
# 1408593           2.0
# 1800042           2.0
# 232880            1.0
# 2463691           2.0
# 2868461           1.0
# 37703             1.0
# 1804353           1.0
# 2815046           1.0
# 844011            1.0
# 1963158           1.0
# 2146846           1.0
# 1606497           1.0
# 676666            1.0
# 141277            2.0
# 147033            1.0
# 953368            1.0
# 1424681           1.0
# 2294588           1.0
# 2339517           2.0
# 985880            1.0
# 1056375           1.0
# 1549173           3.0
# 952346            1.0
# 2805987           1.0
# 1993738           1.0

# %%
# 4
sns.relplot(x='date',y='item_id',data=sales_data_sample, size=(20, 6))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-ccd8923efa44> in <module>
#       1 # 4
# ----> 2 sns.relplot(x='date',y='item_id',data=sales_data_sample, size=(20, 6))
#
# D:\Software\Anaconda\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1663         sizes=sizes, size_order=size_order, size_norm=size_norm,
#    1664         markers=markers, dashes=dashes, style_order=style_order,
# -> 1665         legend=legend,
#    1666     )
#    1667
#
# D:\Software\Anaconda\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     889
#     890         plot_data = self.establish_variables(
# --> 891             x, y, hue, size, style, units, data
#     892         )
#     893
#
# D:\Software\Anaconda\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     155                 units=units
#     156             )
# --> 157             plot_data = pd.DataFrame(plot_data)
#     158
#     159         # Option 3:
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     376                         f"length {len(index)}"
#     377                     )
# --> 378                     raise ValueError(msg)
#     379             else:
#     380                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 2 does not match index length 50

# %%
# 5 & 6
for index, row in sales_data_sample.iterrows():
    row['date'] = pd.to_datetime(row['date'])
    
sns.relplot(x='date',y='item_id',data=sales_data_sample, sizes=(20, 6))

# %%
# Visualisation de variables catégoriques
# 1
cate_data = pd.read_csv("D://Etudes/HiTeMa M2/BigData/data/ibm_hr_attrition.csv")

# %%
cate_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# 2
sns.catplot(x="Department", y="JobSatisfaction", data=cate_data)

# %%
# 3
sns.boxplot(x="Department", y="JobSatisfaction", data=cate_data)

# %%
# 6
cate_data.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]>

# %%
# 9
for index, row in cate_data.iterrows():
    if row['Attrition'] == 1:
        row['Attrition'] = 'Yes'
    elif row['Attrition'] == 0:
        row['Attrition'] = 'No'

# %%
plt.bar(cate_data.EducationField,cate_data.Attrition)
# Out:
# <BarContainer object of 1470 artists>

# %%
# Visualisation d’une distribution 
# 2
sns.distplot(cate_data.MonthlyIncome)

# %%
cate_data_limit = cate_data[(cate_data.MonthlyIncome > 0) & (cate_data.MonthlyIncome < 5000)]

sns.distplot(cate_data_limit.MonthlyIncome)

# %%
# Visualisation d’une relation linéaire 
# 2
sns.lmplot(y='DistanceFromHome',x='YearsAtCompany',data=cate_data)

# %%
# 3
sns.lmplot(y='DistanceFromHome',x='YearsWithCurrManager',data=cate_data)

# %%
cate_data.info
# Out:
# <bound method DataFrame.info of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]>
